# %%
# imports

from tensorflow import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Embedding, SimpleRNN
import numpy as np

# %%
# data preparation

lines = open("data100.csv").readlines()
data = []

# tokenize strings
tokenizer = keras.preprocessing.text.Tokenizer(
    num_words=None,
    filters=""" .,?!#$%&()*+-<=>@[\\]^_`{|}~\t\n'"/ """,
    lower=False,
    split=" ",
)
tokenizer.fit_on_texts(lines)
for line in lines:
    line = line.split(" ")
    data.append(tokenizer.texts_to_sequences(line))


# split into groups of 50 words
features = []  # the 48 words that the ai is trained on
labels = []  # the next word that they ai should guess
for text in data:
    for i in range(50, len(text), 50):
        words = []
        for i in text[i - 50 : i]:
            try:
                words.append((i[0]-1)/len(tokenizer.word_index))
            except IndexError:
                words.append(0)

        features.append(words[:48])
        labels.append(words[49])
train_features = np.array(features[: int(len(features) * 0.8)])
train_labels = np.array(labels[: int(len(features) * 0.8)])
test_features = np.array(features[int(len(features) * 0.8) :])
test_labels = np.array(labels[int(len(features) * 0.8) :])

# one-hot encoding
# train_labels = keras.utils.to_categorical(train_labels)
# test_labels = keras.utils.to_categorical(test_labels)

print(f"Number of data points: {len(labels)}")
# Out:
# Number of data points: 8009

# %%
# model

model = Sequential()

# input layer
model.add(
    Embedding(
        input_dim=1,
        input_length=48,
        output_dim=100,
        trainable=False,
        mask_zero=True,
    )
)

# processing layers
model.add(LSTM(64, return_sequences=False, dropout=0.1, recurrent_dropout=0.1)) # 
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(1, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 48, 100)           100
#
#  lstm (LSTM)                 (None, 64)                42240
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 46565 (181.89 KB)
# Trainable params: 46465 (181.50 KB)
# Non-trainable params: 100 (400.00 Byte)
# _________________________________________________________________

# %%
# train model

model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

model.fit(
    train_features,
    train_labels,
    validation_data=(test_features, test_labels),
    epochs=150,
    verbose=2,
    shuffle=True,
)

scores = model.evaluate(test_features, test_labels,verbose=0) 
print('Test accuracy:', scores[1])
# Out:
# Epoch 1/150
# 201/201 - 8s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 8s/epoch - 41ms/step
# Epoch 2/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 3/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 35ms/step
# Epoch 4/150
# 201/201 - 9s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 9s/epoch - 45ms/step
# Epoch 5/150
# 201/201 - 9s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 9s/epoch - 46ms/step
# Epoch 6/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 7/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 8/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 9/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 32ms/step
# Epoch 10/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 11/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 12/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 36ms/step
# Epoch 13/150
# 201/201 - 9s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 9s/epoch - 43ms/step
# Epoch 14/150
# 201/201 - 11s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 11s/epoch - 54ms/step
# Epoch 15/150
# 201/201 - 9s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 9s/epoch - 47ms/step
# Epoch 16/150
# 201/201 - 10s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 10s/epoch - 50ms/step
# Epoch 17/150
# 201/201 - 9s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 9s/epoch - 42ms/step
# Epoch 18/150
# 201/201 - 9s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 9s/epoch - 43ms/step
# Epoch 19/150
# 201/201 - 9s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 9s/epoch - 43ms/step
# Epoch 20/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 21/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 22/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 23/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 24/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 25/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 26/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 27/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 28/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 29/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 30/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 31/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 32/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 33/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 34/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 35/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 36/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 37/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 38/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 39/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 40/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 41/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 42/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 43/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 44/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 45/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 46/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 47/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 48/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 49/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 50/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 51/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 52/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 53/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 54/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 55/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 56/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 57/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 58/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 59/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 60/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 34ms/step
# Epoch 61/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 62/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 63/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 64/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 65/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 35ms/step
# Epoch 66/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 67/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 68/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 69/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 70/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 71/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 72/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 73/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 74/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 75/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 76/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 77/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 78/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 79/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 80/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 81/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 82/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 83/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 84/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 85/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 86/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 87/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 88/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 89/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 90/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 91/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 92/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 93/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 94/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 95/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 96/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 97/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 98/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 99/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 100/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 101/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 102/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 103/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 104/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 105/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 106/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 107/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 108/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 32ms/step
# Epoch 109/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 110/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 111/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 112/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 113/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 34ms/step
# Epoch 114/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 115/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 116/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 117/150
# 201/201 - 11s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 11s/epoch - 55ms/step
# Epoch 118/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 36ms/step
# Epoch 119/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 35ms/step
# Epoch 120/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 35ms/step
# Epoch 121/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 34ms/step
# Epoch 122/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 123/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 124/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 125/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 126/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 127/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 128/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 129/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 130/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 131/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 132/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 133/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 134/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 135/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 136/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 137/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 138/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 139/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 140/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 141/150
# 201/201 - 7s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 7s/epoch - 33ms/step
# Epoch 142/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 143/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 144/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 31ms/step
# Epoch 145/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 146/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 147/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 32ms/step
# Epoch 148/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 149/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Epoch 150/150
# 201/201 - 6s - loss: 0.8770 - accuracy: 0.0000e+00 - val_loss: 0.8722 - val_accuracy: 0.0000e+00 - 6s/epoch - 30ms/step
# Test accuracy: 0.0

# %%
# save model

model.save("rnn.keras")
